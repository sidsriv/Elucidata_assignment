# %% [markdown]
# # In this notebook, I will use Principal component analysis (PCA) to answer the question "Can we differentiate different tumours from the multidimensional data using dimensionality reduction".

# %% [markdown]
# ## For initial exploratory analysis, I used Phantasus to load my dataset and perform PCA on it, I used 2-D PCA plot and marked points based on the histological_type column of the dataset. I also experimented with projecting different pairs of Pricipal components to see if anyone of them projects experiment points into distinct points.

# %% [markdown]
# ### The First Principal axis captures 13.9% variance of the whole dataset.
# ### The Second Principal axis captures 11.1% variance of the whole dataset.
# ### The Third Principal axis captures 7.2% variance of the whole dataset.
# ### The Fourth Principal axis captures 4.5% variance of the whole dataset.
# ### So the first four principal axes capture merely 36.7% of the total variance.

# %%
from IPython.display import Image
Image("./newplot.png")

# %%
Image("./newplot (1).png")

# %%
Image("./newplot (2).png")

# %% [markdown]
# # As we can see from the plots, histological_type columns is not a clear indicator to find out Exocrine samples from the Neuroendocrine samples, Looking at the plot between the first and second PC, we can see that almost all the experiments tend to come under one cluster, apart from 8 experiments.
#
# # We can say that these 8 experiments might correspond to the neuroendocrine tumour samples but we are not 100% sure.
#
# # Also, all these 8 samples belong to pancreas-adenocarcinoma-other_subtype class.

# %% [markdown]
# # Explanations to different problems asked
#
# # What does the analysis say about the general behaviour of the different samples?
# ## As mentioned above, alomst all the samples tend to form a single glob, showing similar gene expression values, apart from that we have a second extremely smaller glob of around 8 samples.
#
# # Are the neuroendocrine tumors clearly separable from the adenocarcinoma tumors?
# ## From the PCA plots, I can say that the Neuroendocrine tumours are not clearly seperable from the adenocarciroma tumours. Although, as mentioned in litreature that neuroendocrine tumours comrise of 85% of the total pancreatic cancer cases, if we assume that the sample size of 183 is unbiased.. we should be seeing 20 samples that should be of neuroendocrine cancer and we're getting around 8 samples, statistically that is not significant.
#
# # What can be said about the variance of the PCA?
# ## The first principal component explains 13.1% while the second pricipal component explains 11.1% so collectively only 24% variance is explained by our top two components, these results suggests that our gene expression values are noisy. PCA, being derived from noisy data, is itself noisy.
