# %% [markdown]
# # In this notebook, basic exploration of the given dataset is being done. Since the dataset given initially had a duplicate gene_id probe (total 18466 rows), I used Phantasus to collapse common gene_id based on maximum median probe condition and I finally ended up with 18465 rows as there was only single gene_id which had two values. I downloaded the dataset from the phantasus platform for further analysis

# %% [markdown]
# # Since I'm using python programming language for the analysis, I used the cmapPy module for reading the GTC file to parse the whole file in form of pandas dataframe

# %%
#Loading necessary modules
from cmapPy.pandasGEXpress.parse import parse
import numpy as np
import pandas as pd

# %%
#loading dataset with redundant gene ID's collapsed
df=parse('./PAAD_collapsed.gct')

# %%
#Shape of the dataset
df.data_df.shape
# Out:
# (18465, 183)

# %% [markdown]
# ## Taking a look at column metadata of the 183 example, we find information rich columns containing general information of the experiments along with information about the histological_type information of the different experiments

# %%
#looking at Column metadata to find out 
df.col_metadata_df
# Out:
# chd                      participant_id          sample_type  mRNAseq_cluster  \
# cid
# aab1-Primary solid Tumor           aab1  Primary solid Tumor              1.0
# aab4-Primary solid Tumor           aab4  Primary solid Tumor              2.0
# aab6-Primary solid Tumor           aab6  Primary solid Tumor              3.0
# aab8-Primary solid Tumor           aab8  Primary solid Tumor              1.0
# aab9-Primary solid Tumor           aab9  Primary solid Tumor              4.0
# aaba-Primary solid Tumor           aaba  Primary solid Tumor              3.0
# aabe-Primary solid Tumor           aabe  Primary solid Tumor              3.0
# aabf-Primary solid Tumor           aabf  Primary solid Tumor              2.0
# aabh-Primary solid Tumor           aabh  Primary solid Tumor              2.0
# aabi-Primary solid Tumor           aabi  Primary solid Tumor              3.0
# aabk-Primary solid Tumor           aabk  Primary solid Tumor              2.0
# ...

# %%
#looking at histological Column 
df.col_metadata_df.histological_type
# Out:
# cid
# aab1-Primary solid Tumor               pancreas-adenocarcinoma-other subtype
# aab4-Primary solid Tumor               pancreas-adenocarcinoma-other subtype
# aab6-Primary solid Tumor                 pancreas-adenocarcinoma ductal type
# aab8-Primary solid Tumor                 pancreas-adenocarcinoma ductal type
# aab9-Primary solid Tumor                 pancreas-adenocarcinoma ductal type
# aaba-Primary solid Tumor                 pancreas-adenocarcinoma ductal type
# aabe-Primary solid Tumor                 pancreas-adenocarcinoma ductal type
# aabf-Primary solid Tumor                 pancreas-adenocarcinoma ductal type
# aabh-Primary solid Tumor               pancreas-adenocarcinoma-other subtype
# aabi-Primary solid Tumor               pancreas-adenocarcinoma-other subtype
# aabk-Primary solid Tumor                 pancreas-adenocarcinoma ductal type
# aabo-Primary solid Tumor                 pancreas-adenocarcinoma ductal type
# ...

# %%
#counting histological_type counts
df.col_metadata_df.histological_type.value_counts()
# Out:
# pancreas-adenocarcinoma ductal type                 150
# pancreas-adenocarcinoma-other subtype                27
# pancreas-colloid (mucinous non-cystic) carcinoma      4
# pancreas-undifferentiated carcinoma                   1
# Name: histological_type, dtype: int64

# %% [markdown]
# ## As we can see, we have four kind of histological values along with their value counts. Our task at hand is to find out and filter Exocrine tumour samples from the Neuroendocrine Tumour samples. Looking at the Histological_type values, it is not certain at first about which sampels are really Exocrine and which samples are Neuroendocrine.

# %% [markdown]
# ## Now taking a look at the row_metadata, we find out about gene_id information and the kind of values that it holds.

# %%
#now looking at the gene data
#we can see the names of all the genes
df.row_metadata_df
# Out:
# rhd                              Source
# rid
# A1BG       mRNAseq_RSEM_normalized_log2
# A1CF       mRNAseq_RSEM_normalized_log2
# A2BP1      mRNAseq_RSEM_normalized_log2
# A2LD1      mRNAseq_RSEM_normalized_log2
# A2ML1      mRNAseq_RSEM_normalized_log2
# A2M        mRNAseq_RSEM_normalized_log2
# A4GALT     mRNAseq_RSEM_normalized_log2
# A4GNT      mRNAseq_RSEM_normalized_log2
# AAA1       mRNAseq_RSEM_normalized_log2
# AAAS       mRNAseq_RSEM_normalized_log2
# AACSL      mRNAseq_RSEM_normalized_log2
# AACS       mRNAseq_RSEM_normalized_log2
# AADAC      mRNAseq_RSEM_normalized_log2
# AADAT      mRNAseq_RSEM_normalized_log2
# AAGAB      mRNAseq_RSEM_normalized_log2
# AAK1       mRNAseq_RSEM_normalized_log2
# AAMP       mRNAseq_RSEM_normalized_log2
# AANAT      mRNAseq_RSEM_normalized_log2
# AARS2      mRNAseq_RSEM_normalized_log2
# AARSD1     mRNAseq_RSEM_normalized_log2
# AARS       mRNAseq_RSEM_normalized_log2
# AASDHPPT   mRNAseq_RSEM_normalized_log2
# ...

# %% [markdown]
# ## Finally we look at the normalized RNA_seq values for each gene_id (18465) corresponsing to different experiments (183)

# %%
#now looking looking at gene expression data, this is a matrix having rows as number of genes and columns as number of 
#number of experiments
df.data_df
# Out:
# cid        aab1-Primary solid Tumor  aab4-Primary solid Tumor  \
# rid
# A1BG                            6.4                       5.8
# A1CF                            4.7                       5.7
# A2BP1                          -1.0                       1.1
# A2LD1                           7.5                       6.8
# A2ML1                           6.4                       NaN
# A2M                            14.3                      14.0
# A4GALT                         10.6                      10.2
# A4GNT                           8.8                       5.6
# AAA1                            1.0                      -1.2
# AAAS                            9.4                       9.1
# AACSL                          -1.0                      -0.2
# AACS                           10.2                      10.3
# AADAC                           9.2                       5.0
# AADAT                           4.8                       6.3
# ...

# %% [markdown]
# ## This concludes our exploratory analysis part
# # In the next step we will try to use PCA in order to look into patterns from the dataset and wether we could differentiate Exocrine tumour samples from the Neuroendocrine samples.
